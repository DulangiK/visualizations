# %%
import seaborn as snNew
import pandas as pdNew
import matplotlib.pyplot as plt     
import matplotlib.pyplot as pltNew

ax= plt.subplot()





array=[[30,  0,  0 ,12],
 [ 0, 14,  5 , 1],
 [ 0,  4 ,11 , 4],
 [ 8 , 2,  8 ,27]]

DetaFrame_cm = pdNew.DataFrame(array, range(4), range(4))
snNew.heatmap(DetaFrame_cm, annot=True , ax=ax)

ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.xaxis.set_ticklabels(['First', 'Pass','Second Low','Second Up']); ax.yaxis.set_ticklabels(['First', 'Pass','Second Low','Second Up']);
pltNew.show()

# %%
import seaborn as snNew
import pandas as pdNew
import matplotlib.pyplot as plt     
import matplotlib.pyplot as pltNew

ax= plt.subplot()





array=[[42,  0,  0 , 2],
 [ 0,  9 , 5,  0],
 [ 0,  6 , 7 , 9],
 [ 4 , 1 , 7, 31]]

DetaFrame_cm = pdNew.DataFrame(array, range(4), range(4))
snNew.heatmap(DetaFrame_cm, annot=True ,cmap="crest", ax=ax)

ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.xaxis.set_ticklabels(['First', 'Pass','Second Low','Second Up']); ax.yaxis.set_ticklabels(['First', 'Pass','Second Low','Second Up']);
pltNew.show()

# %%
import seaborn as snNew
import pandas as pdNew
import matplotlib.pyplot as plt     
import matplotlib.pyplot as pltNew

ax= plt.subplot()





array=[[45,  0 , 0,  5],
 [ 0 ,13,  5,  0],
 [ 0 , 3 ,19,  8],
 [ 4 , 0 , 3 ,58]]

DetaFrame_cm = pdNew.DataFrame(array, range(4), range(4))
snNew.heatmap(DetaFrame_cm, annot=True ,cmap="yellowbrick", ax=ax)

ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.xaxis.set_ticklabels(['First', 'Pass','Second Low','Second Up']); ax.yaxis.set_ticklabels(['First', 'Pass','Second Low','Second Up']);
pltNew.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-d9928070ed14> in <module>
#      16
#      17 DetaFrame_cm = pdNew.DataFrame(array, range(4), range(4))
# ---> 18 snNew.heatmap(DetaFrame_cm, annot=True ,cmap="yellowbrick", ax=ax)
#      19
#      20 ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels');
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
# ...

# %%
gist_earth, inferno

# %%
import seaborn as snNew
import pandas as pdNew
import matplotlib.pyplot as plt     
import matplotlib.pyplot as pltNew

ax= plt.subplot()





array=[[42,  0,  0 , 2],
 [ 0,  9 , 5,  0],
 [ 0,  6 , 7 , 9],
 [ 4 , 1 , 7, 31]]

DetaFrame_cm = pdNew.DataFrame(array, range(4), range(4))
snNew.heatmap(DetaFrame_cm, annot=True ,cmap="inferno", ax=ax)

ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.xaxis.set_ticklabels(['First', 'Pass','Second Low','Second Up']); ax.yaxis.set_ticklabels(['First', 'Pass','Second Low','Second Up']);
pltNew.show()

# %%
import seaborn as snNew
import pandas as pdNew
import matplotlib.pyplot as plt     
import matplotlib.pyplot as pltNew

ax= plt.subplot()





array=[[45,  0 , 0,  5],
 [ 0 ,13,  5,  0],
 [ 0 , 3 ,19,  8],
 [ 4 , 0 , 3 ,58]]

DetaFrame_cm = pdNew.DataFrame(array, range(4), range(4))
snNew.heatmap(DetaFrame_cm, annot=True ,cmap="flag", ax=ax)

ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.xaxis.set_ticklabels(['First', 'Pass','Second Low','Second Up']); ax.yaxis.set_ticklabels(['First', 'Pass','Second Low','Second Up']);
pltNew.show()

# %%
import seaborn as snNew
import pandas as pdNew
import matplotlib.pyplot as plt     
import matplotlib.pyplot as pltNew

ax= plt.subplot()





array=[[45,  0 , 0,  5],
 [ 0 ,13,  5,  0],
 [ 0 , 3 ,19,  8],
 [ 4 , 0 , 3 ,58]]

DetaFrame_cm = pdNew.DataFrame(array, range(4), range(4))
snNew.heatmap(DetaFrame_cm, annot=True ,cmap="gist_heat", ax=ax)

ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.xaxis.set_ticklabels(['First', 'Pass','Second Low','Second Up']); ax.yaxis.set_ticklabels(['First', 'Pass','Second Low','Second Up']);
pltNew.show()

# %%
import seaborn as snNew
import pandas as pdNew
import matplotlib.pyplot as plt     
import matplotlib.pyplot as pltNew

ax= plt.subplot()





array=[[45,  0 , 0,  5],
 [ 0 ,13,  5,  0],
 [ 0 , 3 ,19,  8],
 [ 4 , 0 , 3 ,58]]

DetaFrame_cm = pdNew.DataFrame(array, range(4), range(4))
snNew.heatmap(DetaFrame_cm, annot=True ,cmap="Wistia", ax=ax)

ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.xaxis.set_ticklabels(['First', 'Pass','Second Low','Second Up']); ax.yaxis.set_ticklabels(['First', 'Pass','Second Low','Second Up']);
pltNew.show()

# %%
import seaborn as snNew
import pandas as pdNew
import matplotlib.pyplot as plt     
import matplotlib.pyplot as pltNew

ax= plt.subplot()





array=[[45,  0 , 0,  5],
 [ 0 ,13,  5,  0],
 [ 0 , 3 ,19,  8],
 [ 4 , 0 , 3 ,58]]

DetaFrame_cm = pdNew.DataFrame(array, range(4), range(4))
snNew.heatmap(DetaFrame_cm, annot=True ,cmap="summer", ax=ax)

ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.xaxis.set_ticklabels(['First', 'Pass','Second Low','Second Up']); ax.yaxis.set_ticklabels(['First', 'Pass','Second Low','Second Up']);
pltNew.show()

# %%
import seaborn as snNew
import pandas as pdNew
import matplotlib.pyplot as plt     
import matplotlib.pyplot as pltNew

ax= plt.subplot()





array=[[42 , 0 , 0 , 6],
 [ 0 ,13 , 3 , 0],
 [ 0 , 2,19 , 4],
 [ 4 , 0 , 5 ,53]]

DetaFrame_cm = pdNew.DataFrame(array, range(4), range(4))
snNew.heatmap(DetaFrame_cm, annot=True ,cmap="flare", ax=ax)

ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.xaxis.set_ticklabels(['First', 'Pass','Second Low','Second Up']); ax.yaxis.set_ticklabels(['First', 'Pass','Second Low','Second Up']);
pltNew.show()

# %%
import seaborn as snNew
import pandas as pdNew
import matplotlib.pyplot as plt     
import matplotlib.pyplot as pltNew

ax= plt.subplot()





array=[[45,  0 , 0,  5],
 [ 0 ,13,  5,  0],
 [ 0 , 3 ,19,  8],
 [ 4 , 0 , 3 ,58]]

DetaFrame_cm = pdNew.DataFrame(array, range(4), range(4))
snNew.heatmap(DetaFrame_cm, annot=True ,cmap="Spectral", ax=ax)

ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.xaxis.set_ticklabels(['First', 'Pass','Second Low','Second Up']); ax.yaxis.set_ticklabels(['First', 'Pass','Second Low','Second Up']);
pltNew.show()

# %%
import seaborn as snNew
import pandas as pdNew
import matplotlib.pyplot as plt     
import seaborn as sns
import matplotlib.pyplot as pltNew

ax= plt.subplot()





array= [[35,  0,  0, 14],
 [ 0, 15 , 2 , 0],
 [ 0,  1 , 9 , 9],
 [11 , 0 , 7 ,34]]

DetaFrame_cm = pdNew.DataFrame(array, range(4), range(4))
snNew.heatmap(DetaFrame_cm, annot=True ,cmap=sns.dark_palette("seagreen"), ax=ax)

ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.xaxis.set_ticklabels(['First', 'Pass','Second Low','Second Up']); ax.yaxis.set_ticklabels(['First', 'Pass','Second Low','Second Up']);
pltNew.show()

# %%
import seaborn as snNew
import pandas as pdNew
import matplotlib.pyplot as plt     
import seaborn as sns
import matplotlib.pyplot as pltNew

ax= plt.subplot()

array=[[37 , 0 , 1, 11],
 [ 0, 14 , 3,  0],
 [ 1 , 2, 11 , 5],
 [13 , 0 , 6 ,33]]


DetaFrame_cm = pdNew.DataFrame(array, range(4), range(4))
snNew.heatmap(DetaFrame_cm, annot=True ,cmap=sns.dark_palette("#79C"), ax=ax)

ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.xaxis.set_ticklabels(['First', 'Pass','Second Low','Second Up']); ax.yaxis.set_ticklabels(['First', 'Pass','Second Low','Second Up']);
pltNew.show()

# %%
import seaborn as snNew
import pandas as pdNew
import matplotlib.pyplot as plt     
import seaborn as sns
import matplotlib.pyplot as pltNew

ax= plt.subplot()





array=[[45,  0 , 0,  5],
 [ 0 ,13,  5,  0],
 [ 0 , 3 ,19,  8],
 [ 4 , 0 , 3 ,58]]

DetaFrame_cm = pdNew.DataFrame(array, range(4), range(4))
snNew.heatmap(DetaFrame_cm, annot=True ,cmap=sns.dark_palette((20, 60, 50), input="husl"), ax=ax)

ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.xaxis.set_ticklabels(['First', 'Pass','Second Low','Second Up']); ax.yaxis.set_ticklabels(['First', 'Pass','Second Low','Second Up']);
pltNew.show()

# %%
import seaborn as snNew
import pandas as pdNew
import matplotlib.pyplot as plt     
import seaborn as sns
import matplotlib.pyplot as pltNew

ax= plt.subplot()





array=[[45,  0 , 0,  5],
 [ 0 ,13,  5,  0],
 [ 0 , 3 ,19,  8],
 [ 4 , 0 , 3 ,58]]

DetaFrame_cm = pdNew.DataFrame(array, range(4), range(4))
snNew.heatmap(DetaFrame_cm, annot=True ,cmap="Greens", ax=ax)

ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.xaxis.set_ticklabels(['First', 'Pass','Second Low','Second Up']); ax.yaxis.set_ticklabels(['First', 'Pass','Second Low','Second Up']);
pltNew.show()

# %%
import seaborn as snNew
import pandas as pdNew
import matplotlib.pyplot as plt     
import seaborn as sns
import matplotlib.pyplot as pltNew

ax= plt.subplot()





array=[[45,  0 , 0,  5],
 [ 0 ,13,  5,  0],
 [ 0 , 3 ,19,  8],
 [ 4 , 0 , 3 ,58]]

DetaFrame_cm = pdNew.DataFrame(array, range(4), range(4))
snNew.heatmap(DetaFrame_cm, annot=True ,cmap="Purples", ax=ax)

ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.xaxis.set_ticklabels(['First', 'Pass','Second Low','Second Up']); ax.yaxis.set_ticklabels(['First', 'Pass','Second Low','Second Up']);
pltNew.show()

# %%
import seaborn as snNew
import pandas as pdNew
import matplotlib.pyplot as plt     
import seaborn as sns
import matplotlib.pyplot as pltNew

ax= plt.subplot()





array=[[45,  0 , 0,  5],
 [ 0 ,13,  5,  0],
 [ 0 , 3 ,19,  8],
 [ 4 , 0 , 3 ,58]]

DetaFrame_cm = pdNew.DataFrame(array, range(4), range(4))
snNew.heatmap(DetaFrame_cm, annot=True ,cmap="YlGnBu", ax=ax)

ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.xaxis.set_ticklabels(['First', 'Pass','Second Low','Second Up']); ax.yaxis.set_ticklabels(['First', 'Pass','Second Low','Second Up']);
pltNew.show()

# %%
import seaborn as snNew
import pandas as pdNew
import matplotlib.pyplot as plt     
import seaborn as sns
import matplotlib.pyplot as pltNew

ax= plt.subplot()





array=[[45,  0 , 0,  5],
 [ 0 ,13,  5,  0],
 [ 0 , 3 ,19,  8],
 [ 4 , 0 , 3 ,58]]

DetaFrame_cm = pdNew.DataFrame(array, range(4), range(4))
snNew.heatmap(DetaFrame_cm, annot=True ,cmap="BuPu", ax=ax)

ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.xaxis.set_ticklabels(['First', 'Pass','Second Low','Second Up']); ax.yaxis.set_ticklabels(['First', 'Pass','Second Low','Second Up']);
pltNew.show()

# %%
import seaborn as snNew
import pandas as pdNew
import matplotlib.pyplot as plt     
import seaborn as sns
import matplotlib.pyplot as pltNew

ax= plt.subplot()





array=[[45,  0 , 0,  5],
 [ 0 ,13,  5,  0],
 [ 0 , 3 ,19,  8],
 [ 4 , 0 , 3 ,58]]

DetaFrame_cm = pdNew.DataFrame(array, range(4), range(4))
snNew.heatmap(DetaFrame_cm, annot=True , vmin=0, vmax=0.5, ax=ax)

ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.xaxis.set_ticklabels(['First', 'Pass','Second Low','Second Up']); ax.yaxis.set_ticklabels(['First', 'Pass','Second Low','Second Up']);
pltNew.show()

# %%
import seaborn as snNew
import pandas as pdNew
import matplotlib.pyplot as plt     
import seaborn as sns
import matplotlib.pyplot as pltNew

ax= plt.subplot()





array=[[45,  0 , 0,  5],
 [ 0 ,13,  5,  0],
 [ 0 , 3 ,19,  8],
 [ 4 , 0 , 3 ,58]]

DetaFrame_cm = pdNew.DataFrame(array, range(4), range(4))
snNew.heatmap(DetaFrame_cm, annot=True ,vmin=0.5, vmax=0.7, ax=ax)

ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.xaxis.set_ticklabels(['First', 'Pass','Second Low','Second Up']); ax.yaxis.set_ticklabels(['First', 'Pass','Second Low','Second Up']);
pltNew.show()
